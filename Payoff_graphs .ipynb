# %% [markdown]
# # **INTRODUCTION TO OPTIONS**

# %% [markdown]
# [Basics of options](https://corporatefinanceinstitute.com/resources/derivatives/options-calls-and-puts/)

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.35)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.23.5)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2023.11.17)

# %% [markdown]
# **IMPORTING THE LIBRARIES**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from datetime import date


import warnings
warnings.filterwarnings("ignore")

# to fetch data
import yfinance as yf

# %% [markdown]
# **IMPORTING DATA FOR OPTIONS**

# %%
symbol = '^SPX'  #the ticker of the stock whose data is to be taken out
dfo = yf.Ticker(symbol)

# %%
dfo.options  #to get the date of different expiration time
# Out:
# ('2024-01-22',
#  '2024-01-23',
#  '2024-01-24',
#  '2024-01-25',
#  '2024-01-26',
#  '2024-01-29',
#  '2024-01-30',
#  '2024-01-31',
#  '2024-02-01',
#  '2024-02-02',
#  '2024-02-05',
#  '2024-02-06',
#  '2024-02-07',
#  '2024-02-08',
#  '2024-02-09',
#  '2024-02-12',
#  '2024-02-13',
#  '2024-02-14',
#  '2024-02-15',
#  '2024-02-16',
#  '2024-02-20',
#  '2024-02-21',
#  '2024-02-22',
#  '2024-02-23',
#  '2024-02-26',
#  '2024-02-27',
#  '2024-02-29',
#  '2024-03-01',
#  '2024-03-04',
#  '2024-03-15',
#  '2024-03-28',
#  '2024-04-19',
#  '2024-04-30',
#  '2024-05-17',
#  '2024-05-31',
#  '2024-06-21',
#  '2024-06-28',
#  '2024-07-19',
#  '2024-08-16',
#  '2024-09-20',
#  '2024-09-30',
#  '2024-10-18',
#  '2024-11-15',
#  '2024-12-20',
#  '2024-12-31',
#  '2025-01-17',
#  '2025-02-21',
#  '2025-03-21',
#  '2025-06-20',
#  '2025-12-19',
#  '2026-03-20',
#  '2026-12-18',
#  '2027-12-17',
#  '2028-12-15',
#  '2029-12-21')

# %%
print(dfo.options[1])
dfo_exp = dfo.option_chain(dfo.options[1])  #to get data of next recent expiry date
display(dfo_exp)
# Out:
# 2024-01-23
# Options(calls=          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0    SPXW240123C04250000 2024-01-18 20:33:32+00:00  4250.0     531.45  585.9
# 1    SPXW240123C04275000 2024-01-18 20:18:47+00:00  4275.0     503.95  545.9
# 2    SPXW240123C04300000 2024-01-08 20:31:23+00:00  4300.0     463.74  520.9
# 3    SPXW240123C04325000 2024-01-18 20:18:47+00:00  4325.0     453.95  510.4
# 4    SPXW240123C04350000 2024-01-11 15:22:30+00:00  4350.0     422.06  485.5
# ..                   ...                       ...     ...        ...    ...
# 108  SPXW240123C05125000 2024-01-19 17:13:53+00:00  5125.0       0.05    NaN
# 109  SPXW240123C05200000 2024-01-19 20:46:18+00:00  5200.0       0.05    0.0
# 110  SPXW240123C05300000 2024-01-18 20:23:36+00:00  5300.0       0.05    NaN
# 111  SPXW240123C05600000 2024-01-19 20:51:26+00:00  5600.0       0.05    NaN
# 112  SPXW240123C05800000 2023-12-19 21:14:52+00:00  5800.0       0.15    0.0
#
#         ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0    596.00  531.45       0.000000     NaN           NaN           0.553471
# 1    586.00    0.00       0.000000     2.0           2.0           0.531621
# 2    561.10    0.00       0.000000     NaN           7.0           0.512700
# 3    520.50    0.00       0.000000     2.0          22.0           0.635319
# 4    495.60    0.00       0.000000    20.0          20.0           0.610783
# ..      ...     ...            ...     ...           ...                ...
# 108     NaN    0.05            NaN     NaN           NaN           0.000000
# 109    0.10   -0.02     -28.571426    42.0           3.0           0.245613
# 110     NaN    0.05       0.000000     NaN           NaN           0.000000
# 111     NaN    0.05            NaN     NaN           NaN           0.000000
# 112    0.05    0.00       0.000000     NaN        4410.0           0.509771
#
#      inTheMoney contractSize currency
# 0          True      REGULAR      USD
# 1          True      REGULAR      USD
# 2          True      REGULAR      USD
# 3          True      REGULAR      USD
# 4          True      REGULAR      USD
# ..          ...          ...      ...
# 108       False      REGULAR      USD
# 109       False      REGULAR      USD
# 110       False      REGULAR      USD
# 111       False      REGULAR      USD
# 112       False      REGULAR      USD
#
# [113 rows x 14 columns], puts=          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0    SPXW240123P01200000 2024-01-17 15:30:44+00:00  1200.0       0.05    NaN
# 1    SPXW240123P02600000 2023-12-15 20:10:08+00:00  2600.0       0.10    0.0
# 2    SPXW240123P02800000 2024-01-04 18:33:35+00:00  2800.0       0.05    0.0
# 3    SPXW240123P03000000 2024-01-08 15:52:11+00:00  3000.0       0.05    0.0
# 4    SPXW240123P03200000 2024-01-18 19:38:50+00:00  3200.0       0.05    0.0
# ..                   ...                       ...     ...        ...    ...
# 129  SPXW240123P04975000 2024-01-09 20:38:32+00:00  4975.0     213.43  129.5
# 130  SPXW240123P05000000 2024-01-16 15:52:24+00:00  5000.0     217.11  154.4
# 131  SPXW240123P05025000 2024-01-18 16:08:27+00:00  5025.0     267.68  179.4
# 132  SPXW240123P05075000 2024-01-19 16:46:39+00:00  5075.0     275.52    NaN
# 133  SPXW240123P05100000 2024-01-19 17:50:02+00:00  5100.0     286.10  254.4
#
#         ask      change  percentChange  volume  openInterest  \
# 0      0.10    0.050000       0.000000     NaN           NaN
# 1      0.05    0.000000       0.000000     3.0           0.0
# 2      0.10    0.000000       0.000000     1.0           7.0
# 3      0.10    0.000000       0.000000    12.0          54.0
# 4      0.10    0.000000       0.000000   100.0         182.0
# ..      ...         ...            ...     ...           ...
# 129  139.60    0.000000       0.000000     NaN           1.0
# 130  164.60    0.000000       0.000000     1.0           1.0
# 131  189.50    0.000000       0.000000     1.0           4.0
# 132     NaN  275.520000            NaN     NaN           NaN
# 133  264.50  -30.809998      -9.722002     3.0           8.0
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             3.968750       False      REGULAR      USD
# 1             1.656252       False      REGULAR      USD
# 2             1.535159       False      REGULAR      USD
# 3             1.351566       False      REGULAR      USD
# 4             1.179692       False      REGULAR      USD
# ..                 ...         ...          ...      ...
# 129           0.198754        True      REGULAR      USD
# 130           0.224999        True      REGULAR      USD
# 131           0.249092        True      REGULAR      USD
# 132           0.000000        True      REGULAR      USD
# 133           0.321601        True      REGULAR      USD
#
# [134 rows x 14 columns], underlying={'language': 'en-US', 'region': 'US', 'quoteType': 'INDEX', 'typeDisp': 'Index', 'quoteSourceName': 'Delayed Quote', 'triggerable': True, 'customPriceAlertConfidence': 'HIGH', 'currency': 'USD', 'marketState': 'CLOSED', 'regularMarketChangePercent': 1.2313503, 'regularMarketPrice': 4839.81, 'underlyingSymbol': '^GSPC', 'exchange': 'WCB', 'shortName': 'S&P 500 INDEX', 'longName': 'S&P 500 INDEX', 'messageBoardId': 'finmb_INDEXSPX', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EST', 'gmtOffSetMilliseconds': -18000000, 'market': 'us_market', 'esgPopulated': False, 'firstTradeDateMilliseconds': -1325583000000, 'priceHint': 2, 'regularMarketChange': 58.870117, 'regularMarketTime': 1705702549, 'regularMarketDayHigh': 4840.67, 'regularMarketDayRange': '4785.87 - 4840.67', 'regularMarketDayLow': 4785.87, 'regularMarketVolume': 2772118867, 'regularMarketPreviousClose': 4780.94, 'bid': 4790.51, 'ask': 4898.59, 'bidSize': 0, 'askSize': 0, 'fullExchangeName': 'Chicago Options', 'regularMarketOpen': 4796.28, 'averageDailyVolume3Month': 3931754666, 'averageDailyVolume10Day': 3778519000, 'fiftyTwoWeekLowChange': 1030.95, 'fiftyTwoWeekLowChangePercent': 0.27067152, 'fiftyTwoWeekRange': '3808.86 - 4840.67', 'fiftyTwoWeekHighChange': -0.8598633, 'fiftyTwoWeekHighChangePercent': -0.00017763312, 'fiftyTwoWeekLow': 3808.86, 'fiftyTwoWeekHigh': 4840.67, 'fiftyTwoWeekChangePercent': 18.934477, 'fiftyDayAverage': 4628.7124, 'fiftyDayAverageChange': 211.09766, 'fiftyDayAverageChangePercent': 0.04560613, 'twoHundredDayAverage': 4399.578, 'twoHundredDayAverageChange': 440.23193, 'twoHundredDayAverageChangePercent': 0.1000623, 'sourceInterval': 15, 'exchangeDataDelayedBy': 15, 'tradeable': False, 'cryptoTradeable': False, 'symbol': '^SPX'})

# %%
dfo_exp.calls #Data for call options
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0    SPXW240123C04250000 2024-01-18 20:33:32+00:00  4250.0     531.45  585.9
# 1    SPXW240123C04275000 2024-01-18 20:18:47+00:00  4275.0     503.95  545.9
# 2    SPXW240123C04300000 2024-01-08 20:31:23+00:00  4300.0     463.74  520.9
# 3    SPXW240123C04325000 2024-01-18 20:18:47+00:00  4325.0     453.95  510.4
# 4    SPXW240123C04350000 2024-01-11 15:22:30+00:00  4350.0     422.06  485.5
# ..                   ...                       ...     ...        ...    ...
# 108  SPXW240123C05125000 2024-01-19 17:13:53+00:00  5125.0       0.05    NaN
# 109  SPXW240123C05200000 2024-01-19 20:46:18+00:00  5200.0       0.05    0.0
# 110  SPXW240123C05300000 2024-01-18 20:23:36+00:00  5300.0       0.05    NaN
# 111  SPXW240123C05600000 2024-01-19 20:51:26+00:00  5600.0       0.05    NaN
# 112  SPXW240123C05800000 2023-12-19 21:14:52+00:00  5800.0       0.15    0.0
#
#         ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0    596.00  531.45       0.000000     NaN           NaN           0.553471
# 1    586.00    0.00       0.000000     2.0           2.0           0.531621
# 2    561.10    0.00       0.000000     NaN           7.0           0.512700
# 3    520.50    0.00       0.000000     2.0          22.0           0.635319
# 4    495.60    0.00       0.000000    20.0          20.0           0.610783
# ..      ...     ...            ...     ...           ...                ...
# 108     NaN    0.05            NaN     NaN           NaN           0.000000
# 109    0.10   -0.02     -28.571426    42.0           3.0           0.245613
# 110     NaN    0.05       0.000000     NaN           NaN           0.000000
# 111     NaN    0.05            NaN     NaN           NaN           0.000000
# 112    0.05    0.00       0.000000     NaN        4410.0           0.509771
#
#      inTheMoney contractSize currency
# 0          True      REGULAR      USD
# 1          True      REGULAR      USD
# 2          True      REGULAR      USD
# 3          True      REGULAR      USD
# 4          True      REGULAR      USD
# ..          ...          ...      ...
# 108       False      REGULAR      USD
# 109       False      REGULAR      USD
# 110       False      REGULAR      USD
# 111       False      REGULAR      USD
# 112       False      REGULAR      USD
#
# [113 rows x 14 columns]

# %%
dfo_exp.puts #Data for put options
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0    SPXW240123P01200000 2024-01-17 15:30:44+00:00  1200.0       0.05    NaN
# 1    SPXW240123P02600000 2023-12-15 20:10:08+00:00  2600.0       0.10    0.0
# 2    SPXW240123P02800000 2024-01-04 18:33:35+00:00  2800.0       0.05    0.0
# 3    SPXW240123P03000000 2024-01-08 15:52:11+00:00  3000.0       0.05    0.0
# 4    SPXW240123P03200000 2024-01-18 19:38:50+00:00  3200.0       0.05    0.0
# ..                   ...                       ...     ...        ...    ...
# 129  SPXW240123P04975000 2024-01-09 20:38:32+00:00  4975.0     213.43  129.5
# 130  SPXW240123P05000000 2024-01-16 15:52:24+00:00  5000.0     217.11  154.4
# 131  SPXW240123P05025000 2024-01-18 16:08:27+00:00  5025.0     267.68  179.4
# 132  SPXW240123P05075000 2024-01-19 16:46:39+00:00  5075.0     275.52    NaN
# 133  SPXW240123P05100000 2024-01-19 17:50:02+00:00  5100.0     286.10  254.4
#
#         ask      change  percentChange  volume  openInterest  \
# 0      0.10    0.050000       0.000000     NaN           NaN
# 1      0.05    0.000000       0.000000     3.0           0.0
# 2      0.10    0.000000       0.000000     1.0           7.0
# 3      0.10    0.000000       0.000000    12.0          54.0
# 4      0.10    0.000000       0.000000   100.0         182.0
# ..      ...         ...            ...     ...           ...
# 129  139.60    0.000000       0.000000     NaN           1.0
# 130  164.60    0.000000       0.000000     1.0           1.0
# 131  189.50    0.000000       0.000000     1.0           4.0
# 132     NaN  275.520000            NaN     NaN           NaN
# 133  264.50  -30.809998      -9.722002     3.0           8.0
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             3.968750       False      REGULAR      USD
# 1             1.656252       False      REGULAR      USD
# 2             1.535159       False      REGULAR      USD
# 3             1.351566       False      REGULAR      USD
# 4             1.179692       False      REGULAR      USD
# ..                 ...         ...          ...      ...
# 129           0.198754        True      REGULAR      USD
# 130           0.224999        True      REGULAR      USD
# 131           0.249092        True      REGULAR      USD
# 132           0.000000        True      REGULAR      USD
# 133           0.321601        True      REGULAR      USD
#
# [134 rows x 14 columns]

# %%
#run this tab to make you aware of the latest price of apple stock

symbol = '^SPX'
end = date.today()
start = end.replace(year = 2022)


# Read data
df = yf.download(symbol,start,end)

df.tail()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-01-12  4791.180176  4802.399902  4768.979980  4783.830078  4783.830078
# 2024-01-16  4772.350098  4782.339844  4747.120117  4765.979980  4765.979980
# 2024-01-17  4739.129883  4744.229980  4714.819824  4739.209961  4739.209961
# 2024-01-18  4760.100098  4785.790039  4740.569824  4780.939941  4780.939941
# 2024-01-19  4796.279785  4842.069824  4785.870117  4839.810059  4839.810059
#
#                 Volume
# Date
# 2024-01-12  3486340000
# 2024-01-16  4260550000
# 2024-01-17  3928600000
# 2024-01-18  4019000000
# 2024-01-19  4287200000

# %% [markdown]
# # **PAYOFF FROM CALL AND PUT OPTIONS**

# %% [markdown]
# # **Call option**
# payoff=max(-C, S - X - C)

# %% [markdown]
# # **Put option**
# payoff=max(-P, X - S - P)
#
# P and C are premiums of calls and puts
#
# S is the stock price
#
# X is the strike price

# %%
def payoff(option_type, premium, S, X):
  if(option_type=='C'):
    Payoff = max(-1*premium,S-X-premium)
    return Payoff
  elif(option_type=='P'):
    Payoff = max(-1*premium,X-S-premium)
    return Payoff
  else: print("option type not supported")
  #your code here

# %% [markdown]
# Checking the output of payoff function

# %%
payoff('C', 10, 120,100)  #answer displayed should be 10
# Out:
# 10

# %%
payoff('Z', 10, 120, 100)  #answer displayed should be option type not supported
# Out:
# option type not supported

# %%
payoff('P', 10, 120, 100)  #answer displayed should be -10
# Out:
# -10

# %% [markdown]
# # **PAYOFF GRAPHS**

# %% [markdown]
# **CALL OPTION**

# %%
X = dfo_exp.calls['strike'][0]
premium = dfo_exp.calls['lastPrice'][0]
X
# Out:
# 4250.0

# %%
StockPrice = np.arange(0, 6000)
Payoff = [payoff('C', premium, i, X) for i in StockPrice]

# %%
#PLOTTING THE PAYOFF GRAPH FOR CALL OPTION
plt.plot(StockPrice, Payoff, label = 'payoff line')
plt.xlabel('Stock Price')
plt.ylabel('payoff')
plt.title('Call option Payoff at Expiry')
plt.grid(True)

#breakeven point is when payoff is 0 or S=X+C
plt.plot(X+premium, 0, 'ro', label = 'breakeven point')
plt.legend()

# %% [markdown]
# **PUT OPTION**

# %%
X = dfo_exp.puts['strike'][len(dfo_exp.puts)-1]
premium = dfo_exp.puts['lastPrice'][len(dfo_exp.puts)-1]
premium
# Out:
# 286.1

# %%
StockPrice = np.arange(0, 6000)
Payoff = [payoff('P', premium, i, X) for i in StockPrice]

# %%
plt.plot(StockPrice, Payoff, label = 'payoff line')
plt.xlabel('Stock Price')
plt.ylabel('payoff')
plt.title('Put option Payoff at Expiry')
plt.grid(True)

#breakeven point is when payoff is 0 or X=S+C
plt.plot(X-premium, 0, 'ro', label = 'breakeven point')
plt.legend()
